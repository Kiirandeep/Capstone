# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %matplotlib inline

# %%
import warnings
warnings.filterwarnings('ignore')
pd.set_option('display.max_columns', None)

# %%
oecd_all = pd.read_csv('../data/MIG_NUP_RATES_GENDER_12042024205534698.csv')

# %%
#dropping repeated cols
oecd_all1 = oecd_all[['Country','Place of birth', 'Gender', 'Rate', 'Year', 'Unit','Value']]

# %%
len(oecd_all1.Country.value_counts())
# Out:
# 35

# %%
oecd_all1.describe()
# Out:
#                Year         Value
# count  12633.000000  12633.000000
# mean    2011.396185     49.628077
# std        6.534134     30.315785
# min     2000.000000      0.000000
# 25%     2006.000000     10.700000
# 50%     2012.000000     63.900000
# 75%     2017.000000     74.400000
# max     2022.000000     94.100000

# %%
oecd_all1.Country.unique()
# Out:
# array(['Australia', 'Austria', 'Belgium', 'Canada', 'Czechia', 'Denmark',
#        'Finland', 'France', 'Germany', 'Greece', 'Hungary', 'Iceland',
#        'Ireland', 'Italy', 'Luxembourg', 'Mexico', 'Netherlands',
#        'New Zealand', 'Norway', 'Poland', 'Portugal', 'Slovak Republic',
#        'Spain', 'Sweden', 'Switzerland', 'Türkiye', 'United Kingdom',
#        'United States', 'Chile', 'Estonia', 'Israel', 'Slovenia',
#        'OECD - Total', 'Latvia', 'Lithuania'], dtype=object)

# %%
oecd_all1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12633 entries, 0 to 12632
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country         12633 non-null  object
#  1   Place of birth  12633 non-null  object
#  2   Gender          12633 non-null  object
#  3   Rate            12633 non-null  object
#  4   Year            12633 non-null  int64
#  5   Unit            12633 non-null  object
#  6   Value           12633 non-null  float64
# dtypes: float64(1), int64(1), object(5)
# memory usage: 691.0+ KB

# %%
oecd_us = oecd_all1.loc[oecd_all1.Country == 'United States']
oecd_us = oecd_us.loc[(oecd_us.Rate== 'Unemployment rate') & (oecd_us.Gender == 'Total')].reset_index(drop = True)
us_df = oecd_us.groupby('Year')['Value'].sum().to_frame().reset_index()
us_df
# Out:
#     Year  Value
# 0   2000    8.4
# 1   2001   10.3
# 2   2002   12.3
# 3   2003   12.7
# 4   2004   11.3
# 5   2005   10.1
# 6   2006    9.1
# 7   2007    9.3
# 8   2008   11.9
# 9   2009   19.1
# 10  2010   19.7
# 11  2011   18.3
# 12  2012   16.4
# 13  2013   14.7
# 14  2014   12.3
# 15  2015   10.6
# 16  2016    9.5
# 17  2017    8.6
# 18  2018    7.6
# 19  2019    7.0
# 20  2020   16.9
# 21  2021   11.1
# 22  2022    7.4

# %%
oecd_us.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46 entries, 0 to 45
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country         46 non-null     object
#  1   Place of birth  46 non-null     object
#  2   Gender          46 non-null     object
#  3   Rate            46 non-null     object
#  4   Year            46 non-null     int64
#  5   Unit            46 non-null     object
#  6   Value           46 non-null     float64
# dtypes: float64(1), int64(1), object(5)
# memory usage: 2.6+ KB

# %%
plt.figure(figsize = (15,5))
plt.plot(us_df['Year'],us_df['Value']);

# %%
oecd_aus = oecd_all1.loc[oecd_all1.Country == 'Australia']
oecd_aus = oecd_aus.loc[(oecd_aus.Rate== 'Unemployment rate') & (oecd_aus.Gender == 'Total')].reset_index(drop = True)

oecd_aus = oecd_aus.groupby('Year')['Value'].sum().to_frame().reset_index()
oecd_aus
# Out:
#     Year  Value
# 0   2000   13.0
# 1   2001   14.0
# 2   2002   13.1
# 3   2003   12.3
# 4   2004   11.0
# 5   2005   10.3
# 6   2006    9.9
# 7   2007    9.2
# 8   2008    8.8
# 9   2009   12.1
# 10  2010   10.7
# 11  2011   10.4
# 12  2012   10.7
# 13  2013   11.6
# 14  2014   12.4
# 15  2015   12.4
# 16  2016   11.8
# 17  2017   11.6
# 18  2018   10.9
# 19  2019   10.7
# 20  2020   13.5
# 21  2021   10.5
# 22  2022    7.5

# %%
oecd_ger = oecd_all1.loc[oecd_all1.Country == 'Germany']
oecd_ger = oecd_ger.loc[(oecd_ger.Rate== 'Unemployment rate') & (oecd_ger.Gender == 'Total')].reset_index(drop = True)

oecd_ger = oecd_ger.groupby('Year')['Value'].sum().to_frame().reset_index()
oecd_ger
# Out:
#     Year  Value
# 0   2000   18.0
# 1   2001   17.2
# 2   2002   18.5
# 3   2003   22.1
# 4   2004   24.4
# 5   2005   27.5
# 6   2006   26.0
# 7   2007   22.4
# 8   2008   18.9
# 9   2009   20.1
# 10  2010   17.4
# 11  2011   14.5
# 12  2012   13.4
# 13  2013   12.9
# 14  2014   12.4
# 15  2015   11.8
# 16  2016   10.4
# 17  2017    9.7
# 18  2018    8.9
# 19  2019    8.2
# 20  2020    9.9
# 21  2021    9.5
# 22  2022    8.2

# %%
oecd_uk = oecd_all1.loc[oecd_all1.Country == 'United Kingdom']
oecd_uk = oecd_uk.loc[(oecd_uk.Rate== 'Unemployment rate') & (oecd_uk.Gender == 'Total')].reset_index(drop = True)

oecd_uk = oecd_uk.groupby('Year')['Value'].sum().to_frame().reset_index()
oecd_uk
# Out:
#     Year  Value
# 0   2000   14.3
# 1   2001   11.8
# 2   2002   12.5
# 3   2003   12.0
# 4   2004   11.8
# 5   2005   11.6
# 6   2006   12.8
# 7   2007   12.6
# 8   2008   12.3
# 9   2009   16.0
# 10  2010   16.0
# 11  2011   17.5
# 12  2012   17.1
# 13  2013   16.4
# 14  2014   13.2
# 15  2015   11.6
# 16  2016   10.3
# 17  2017    9.4
# 18  2018    8.7
# 19  2019    8.0
# 20  2021    8.9
# 21  2022    8.4

# %%
oecd_fran = oecd_all1.loc[oecd_all1.Country == 'France']
oecd_fran = oecd_fran.loc[(oecd_fran.Rate== 'Unemployment rate') & (oecd_fran.Gender == 'Total')].reset_index(drop = True)

oecd_fran = oecd_fran.groupby('Year')['Value'].sum().to_frame().reset_index()
oecd_fran
# Out:
#     Year  Value
# 0   2000   26.1
# 1   2001   22.1
# 2   2002   22.2
# 3   2003   22.8
# 4   2004   23.0
# 5   2005   22.6
# 6   2006   22.6
# 7   2007   20.5
# 8   2008   19.0
# 9   2009   23.9
# 10  2010   23.1
# 11  2011   24.0
# 12  2012   23.6
# 13  2013   25.3
# 14  2014   26.1
# 15  2015   26.8
# 16  2016   25.9
# 17  2017   24.0
# 18  2018   22.9
# 19  2019   20.9
# 20  2020   19.9
# 21  2021   19.6
# 22  2022   18.3

# %%
oecd_italy = oecd_all1.loc[oecd_all1.Country == 'Italy']
oecd_italy = oecd_italy.loc[(oecd_italy.Rate== 'Unemployment rate') & (oecd_italy.Gender == 'Total')].reset_index(drop = True)

oecd_italy = oecd_italy.groupby('Year')['Value'].sum().to_frame().reset_index()
oecd_italy
# Out:
#     Year  Value
# 0   2000   23.1
# 1   2001   22.7
# 2   2002   18.1
# 3   2003   15.4
# 4   2004   17.1
# 5   2005   17.6
# 6   2006   15.2
# 7   2007   13.9
# 8   2008   15.1
# 9   2009   18.5
# 10  2010   19.6
# 11  2011   19.7
# 12  2012   24.2
# 13  2013   28.4
# 14  2014   28.7
# 15  2015   27.2
# 16  2016   26.3
# 17  2017   25.2
# 18  2018   24.0
# 19  2019   22.7
# 20  2020   21.3
# 21  2021   22.2
# 22  2022   18.5

# %%
oecd_can = oecd_all1.loc[oecd_all1.Country == 'Canada']
oecd_can = oecd_can.loc[(oecd_can.Rate== 'Unemployment rate') & (oecd_can.Gender == 'Total')].reset_index(drop = True)

oecd_can = oecd_can.groupby('Year')['Value'].sum().to_frame().reset_index()
oecd_can
# Out:
#     Year  Value
# 0   2008   13.0
# 1   2009   18.1
# 2   2010   17.5
# 3   2011   16.0
# 4   2012   15.5
# 5   2013   15.1
# 6   2014   14.8
# 7   2015   14.4
# 8   2016   14.5
# 9   2017   13.1
# 10  2018   12.1
# 11  2019   11.8
# 12  2020   20.0
# 13  2021   15.5
# 14  2022   10.9

# %%
oecd_nl = oecd_all1.loc[oecd_all1.Country == 'Netherlands']
oecd_nl = oecd_nl.loc[(oecd_nl.Rate== 'Unemployment rate') & (oecd_nl.Gender == 'Total')].reset_index(drop = True)

oecd_nl = oecd_nl.groupby('Year')['Value'].sum().to_frame().reset_index()
oecd_nl
# Out:
#     Year  Value
# 0   2000    8.5
# 1   2001    6.2
# 2   2002    7.5
# 3   2003   11.5
# 4   2004   14.1
# 5   2005   14.4
# 6   2006   14.3
# 7   2007   10.7
# 8   2008    9.1
# 9   2009   11.4
# 10  2010   12.2
# 11  2011   13.2
# 12  2012   16.4
# 13  2013   19.9
# 14  2014   19.6
# 15  2015   18.3
# 16  2016   16.0
# 17  2017   13.2
# 18  2018   10.4
# 19  2019    9.0
# 20  2020   13.0
# 21  2021   12.0
# 22  2022    8.9

# %% [markdown]
# oecd_aus.to_csv('australia.csv')
# us_df.to_csv('USA.csv')
# oecd_ger.to_csv('germany.csv')
# oecd_uk.to_csv('uk.csv')
# oecd_fran.to_csv('france.csv')
# oecd_italy.to_csv('italy.csv')
# oecd_can.to_csv('can.csv')
# oecd_nl.to_csv('nl.csv')
