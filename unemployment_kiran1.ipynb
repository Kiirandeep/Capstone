# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %matplotlib inline

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
oecd_all = pd.read_csv('data/MIG_NUP_RATES_GENDER_12042024205534698.csv')

# %%
#dropping repeated cols
oecd_all1 = oecd_all[['Country','Place of birth', 'Gender', 'Rate', 'Year', 'Unit','Value']]

# %%
len(oecd_all1.Country.value_counts())
# Out:
# 35

# %%
oecd_all1.loc[oecd_all1.Country == 'United States']
# Out:
#              Country Place of birth Gender                Rate  Year  \
# 5311   United States   Foreign-born    Men     Employment rate  2000
# 5312   United States   Foreign-born    Men     Employment rate  2001
# 5313   United States   Foreign-born    Men     Employment rate  2002
# 5314   United States   Foreign-born    Men     Employment rate  2003
# 5315   United States   Foreign-born    Men     Employment rate  2004
# ...              ...            ...    ...                 ...   ...
# 11728  United States    Native-born  Total  Participation rate  2018
# 11729  United States    Native-born  Total  Participation rate  2019
# 11730  United States    Native-born  Total  Participation rate  2020
# 11731  United States    Native-born  Total  Participation rate  2021
# 11732  United States    Native-born  Total  Participation rate  2022
#
#              Unit  Value
# 5311   Percentage   82.4
# 5312   Percentage   81.4
# 5313   Percentage   80.1
# 5314   Percentage   80.2
# ...

# %%
oecd_all1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12633 entries, 0 to 12632
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country         12633 non-null  object
#  1   Place of birth  12633 non-null  object
#  2   Gender          12633 non-null  object
#  3   Rate            12633 non-null  object
#  4   Year            12633 non-null  int64
#  5   Unit            12633 non-null  object
#  6   Value           12633 non-null  float64
# dtypes: float64(1), int64(1), object(5)
# memory usage: 691.0+ KB

# %%
oecd_all1.describe()
# Out:
#                Year         Value
# count  12633.000000  12633.000000
# mean    2011.396185     49.628077
# std        6.534134     30.315785
# min     2000.000000      0.000000
# 25%     2006.000000     10.700000
# 50%     2012.000000     63.900000
# 75%     2017.000000     74.400000
# max     2022.000000     94.100000

# %% [markdown]
# plt.figure(figsize = (15,5))
# plt.plot(oecd_all1['Year'],oecd_all1['Value' == 2012])

# %% [markdown]
# ### LAUS Data

# %%
df_data_alaska = pd.read_csv('C:/Users/Kiran/Desktop/NSS/Capstone/data/laus/data_alaska',sep='\t',header=(0))
df_data_alaska.columns = df_data_alaska.columns.str.lower().str.strip()
df_data_alaska
# Out:
#                             series_id  year period     value footnote_codes
# 0      LASST020000000000003            1976    M01       7.1            NaN
# 1      LASST020000000000003            1976    M02       7.1            NaN
# 2      LASST020000000000003            1976    M03       7.0            NaN
# 3      LASST020000000000003            1976    M04       6.9            NaN
# 4      LASST020000000000003            1976    M05       6.9            NaN
# ...                               ...   ...    ...       ...            ...
# 72065  LAUST020000000000009            2023    M11  549204.0              R
# 72066  LAUST020000000000009            2023    M12  549367.0              R
# 72067  LAUST020000000000009            2023    M13  548204.0              R
# 72068  LAUST020000000000009            2024    M01  549553.0            NaN
# 72069  LAUST020000000000009            2024    M02  549706.0            NaN
#
# [72070 rows x 5 columns]

# %%
df_data_alaska.columns
# Out:
# Index(['series_id', 'year', 'period', 'value', 'footnote_codes'], dtype='object')

# %%
df_data_california = pd.read_csv('C:/Users/Kiran/Desktop/NSS/Capstone/data/laus/data_california',sep='\t',header=(0))
df_data_california.columns = df_data_california.columns.str.lower().str.strip()
df_data_california
# Out:
#                              series_id  year period       value footnote_codes
# 0       LASBS060000000000003            1976    M01         9.4            NaN
# 1       LASBS060000000000003            1976    M02         9.4            NaN
# 2       LASBS060000000000003            1976    M03         9.3            NaN
# 3       LASBS060000000000003            1976    M04         9.2            NaN
# 4       LASBS060000000000003            1976    M05         9.1            NaN
# ...                                ...   ...    ...         ...            ...
# 671019  LAUST060000000000009            2023    M11  31162587.0              R
# 671020  LAUST060000000000009            2023    M12  31168717.0              R
# 671021  LAUST060000000000009            2023    M13  31124355.0              R
# 671022  LAUST060000000000009            2024    M01  31174033.0            NaN
# 671023  LAUST060000000000009            2024    M02  31178599.0            NaN
#
# ...

# %%
df_data_hawaii = pd.read_csv('C:/Users/Kiran/Desktop/NSS/Capstone/data/laus/data_hawaii',sep='\t',header=(0))
df_data_hawaii.columns = df_data_hawaii.columns.str.lower().str.strip()
df_data_hawaii
# Out:
#                             series_id  year period      value footnote_codes
# 0      LASST150000000000003            1976    M01        9.8            NaN
# 1      LASST150000000000003            1976    M02        9.8            NaN
# 2      LASST150000000000003            1976    M03        9.8            NaN
# 3      LASST150000000000003            1976    M04        9.7            NaN
# 4      LASST150000000000003            1976    M05        9.4            NaN
# ...                               ...   ...    ...        ...            ...
# 23793  LAUST150000000000009            2023    M11  1124040.0              R
# 23794  LAUST150000000000009            2023    M12  1124033.0              R
# 23795  LAUST150000000000009            2023    M13  1123858.0              R
# 23796  LAUST150000000000009            2024    M01  1124028.0            NaN
# 23797  LAUST150000000000009            2024    M02  1123954.0            NaN
#
# [23798 rows x 5 columns]

# %%
df_data_newyork = pd.read_csv('C:/Users/Kiran/Desktop/NSS/Capstone/data/laus/data_newyork',sep='\t',header=(0))
df_data_newyork.columns = df_data_newyork.columns.str.lower().str.strip()
df_data_newyork
# Out:
#                              series_id  year period       value footnote_codes
# 0       LASBS360000000000003            1976    M01         9.7            NaN
# 1       LASBS360000000000003            1976    M02         9.6            NaN
# 2       LASBS360000000000003            1976    M03         9.6            NaN
# 3       LASBS360000000000003            1976    M04         9.5            NaN
# 4       LASBS360000000000003            1976    M05         9.5            NaN
# ...                                ...   ...    ...         ...            ...
# 370299  LAUST360000000000009            2023    M11  15883950.0              R
# 370300  LAUST360000000000009            2023    M12  15880931.0              R
# 370301  LAUST360000000000009            2023    M13  15892729.0              R
# 370302  LAUST360000000000009            2024    M01  15877293.0            NaN
# 370303  LAUST360000000000009            2024    M02  15873214.0            NaN
#
# ...

# %%
df_data_tenn = pd.read_csv('C:/Users/Kiran/Desktop/NSS/Capstone/data/laus/data_tennessee',sep='\t',header=(0))
df_data_tenn.columns = df_data_tenn.columns.str.lower().str.strip()
df_data_tenn
# Out:
#                              series_id  year period      value footnote_codes
# 0       LASST470000000000003            1976    M01        6.0            NaN
# 1       LASST470000000000003            1976    M02        6.0            NaN
# 2       LASST470000000000003            1976    M03        6.0            NaN
# 3       LASST470000000000003            1976    M04        6.0            NaN
# 4       LASST470000000000003            1976    M05        5.9            NaN
# ...                                ...   ...    ...        ...            ...
# 303889  LAUST470000000000009            2023    M11  5679685.0              R
# 303890  LAUST470000000000009            2023    M12  5686134.0              R
# 303891  LAUST470000000000009            2023    M13  5648703.0              R
# 303892  LAUST470000000000009            2024    M01  5692255.0            NaN
# 303893  LAUST470000000000009            2024    M02  5698442.0            NaN
#
# [303894 rows x 5 columns]

# %%
df_data_texas = pd.read_csv('C:/Users/Kiran/Desktop/NSS/Capstone/data/laus/data_texas',sep='\t',header=(0))
df_data_texas.columns = df_data_texas.columns.str.lower().str.strip()
df_data_texas
# Out:
#                              series_id  year period       value footnote_codes
# 0       LASST480000000000003            1976    M01         5.8            NaN
# 1       LASST480000000000003            1976    M02         5.8            NaN
# 2       LASST480000000000003            1976    M03         5.9            NaN
# 3       LASST480000000000003            1976    M04         5.9            NaN
# 4       LASST480000000000003            1976    M05         5.9            NaN
# ...                                ...   ...    ...         ...            ...
# 927077  LAUST480000000000009            2023    M11  23543046.0              R
# 927078  LAUST480000000000009            2023    M12  23581914.0              R
# 927079  LAUST480000000000009            2023    M13  23362410.0              R
# 927080  LAUST480000000000009            2024    M01  23620186.0            NaN
# 927081  LAUST480000000000009            2024    M02  23658614.0            NaN
#
# ...

# %%
df_data_washington = pd.read_csv('C:/Users/Kiran/Desktop/NSS/Capstone/data/laus/data_washington',sep='\t',header=(0))
df_data_washington.columns = df_data_washington.columns.str.lower().str.strip()
df_data_washington
# Out:
#                              series_id  year period      value footnote_codes
# 0       LASBS530000000000003            1990    M01        6.0            NaN
# 1       LASBS530000000000003            1990    M02        6.0            NaN
# 2       LASBS530000000000003            1990    M03        6.0            NaN
# 3       LASBS530000000000003            1990    M04        6.1            NaN
# 4       LASBS530000000000003            1990    M05        6.1            NaN
# ...                                ...   ...    ...        ...            ...
# 201821  LAUST530000000000009            2023    M11  6278911.0              R
# 201822  LAUST530000000000009            2023    M12  6283111.0              R
# 201823  LAUST530000000000009            2023    M13  6257779.0              R
# 201824  LAUST530000000000009            2024    M01  6286991.0            NaN
# 201825  LAUST530000000000009            2024    M02  6290857.0            NaN
#
# [201826 rows x 5 columns]

# %%
# Concatanate the all the states into one dataframe
df_data_combined_states = pd. DataFrame() 
df_data_combined_states = pd.concat([df_data_alaska, df_data_california, df_data_hawaii, df_data_newyork, df_data_tenn, df_data_texas, df_data_washington])

# %%
df_data_combined_states = df_data_combined_states.reset_index(drop = True)

# %%
df_data_combined_states
# Out:
#                               series_id  year period      value footnote_codes
# 0        LASST020000000000003            1976    M01        7.1            NaN
# 1        LASST020000000000003            1976    M02        7.1            NaN
# 2        LASST020000000000003            1976    M03        7.0            NaN
# 3        LASST020000000000003            1976    M04        6.9            NaN
# 4        LASST020000000000003            1976    M05        6.9            NaN
# ...                                 ...   ...    ...        ...            ...
# 2569993  LAUST530000000000009            2023    M11  6278911.0              R
# 2569994  LAUST530000000000009            2023    M12  6283111.0              R
# 2569995  LAUST530000000000009            2023    M13  6257779.0              R
# 2569996  LAUST530000000000009            2024    M01  6286991.0            NaN
# 2569997  LAUST530000000000009            2024    M02  6290857.0            NaN
#
# ...

# %%
df_ref_measure = pd.read_csv('C:/Users/Kiran/Desktop/NSS/Capstone/data/laus/ref_measure',sep='\t',header=(0))
df_ref_measure.columns = df_ref_measure.columns.str.lower().str.strip()
df_ref_measure
# Out:
#    measure_code                          measure_text
# 0             3                     unemployment rate
# 1             4                          unemployment
# 2             5                            employment
# 3             6                           labor force
# 4             7           employment-population ratio
# 5             8        labor force participation rate
# 6             9  civilian noninstitutional population

# %%
df_ref_period = pd.read_csv('C:/Users/Kiran/Desktop/NSS/Capstone/data/laus/ref_period',sep='\t',header=(0))
df_ref_period.columns = df_ref_period.columns.str.lower().str.strip()
df_ref_period
# Out:
#    period period_abbr     period_name
# 0     M01         JAN         January
# 1     M02         FEB        February
# 2     M03         MAR           March
# 3     M04         APR           April
# 4     M05         MAY             May
# 5     M06         JUN            June
# 6     M07         JUL            July
# 7     M08         AUG          August
# 8     M09         SEP       September
# 9     M10         OCT         October
# 10    M11         NOV        November
# 11    M12         DEC        December
# 12    M13       AN AV  Annual Average

# %%
df_ref_seasonal = pd.read_csv('C:/Users/Kiran/Desktop/NSS/Capstone/data/laus/ref_seasonal',sep='\t',header=(0))
df_ref_seasonal.columns = df_ref_seasonal.columns.str.lower().str.strip()

df_ref_seasonal
# Out:
#   seasonal_code            seasonal_text
# 0             S      Seasonally Adjusted
# 1             U  Not Seasonally Adjusted

# %%
df_ref_series = pd.read_csv('C:/Users/Kiran/Desktop/NSS/Capstone/data/laus/ref_series',sep='\t',header=(0))
df_ref_series.columns = df_ref_series.columns.str.lower().str.strip()
df_ref_series.columns
# Out:
# Index(['series_id', 'area_type_code', 'area_code', 'measure_code', 'seasonal',
#        'srd_code', 'series_title', 'footnote_codes', 'begin_year',
#        'begin_period', 'end_year', 'end_period'],
#       dtype='object')

# %%
df_ref_series.head(5)
# Out:
#                         series_id area_type_code        area_code  \
# 0  LASBS060000000000003                        L  BS0600000000000
# 1  LASBS060000000000004                        L  BS0600000000000
# 2  LASBS060000000000005                        L  BS0600000000000
# 3  LASBS060000000000006                        L  BS0600000000000
# 4  LASBS120000000000003                        L  BS1200000000000
#
#    measure_code seasonal  srd_code  \
# 0             3        S         6
# 1             4        S         6
# 2             5        S         6
# 3             6        S         6
# 4             3        S        12
#
#                                         series_title footnote_codes  \
# 0  Unemployment Rate: Balance of California, stat...            NaN
# 1  Unemployment: Balance of California, state les...            NaN
# 2  Employment: Balance of California, state less ...            NaN
# 3  Labor Force: Balance of California, state less...            NaN
# ...

# %%
df_ref_series.footnote_codes.unique()
# Out:
# array([nan, 'A'], dtype=object)

# %%
df_ref_states = pd.read_csv('C:/Users/Kiran/Desktop/NSS/Capstone/data/laus/ref_states',sep='\t',header=(0))
df_ref_states.columns = df_ref_states.columns.str.lower().str.strip()
df_ref_states
# Out:
#     srd_code                      srd_text
# 0          1                       Alabama
# 1          2                        Alaska
# 2          4                       Arizona
# 3          5                      Arkansas
# 4          6                    California
# 5          8                      Colorado
# 6          9                   Connecticut
# 7         10                      Delaware
# 8         11          District of Columbia
# 9         12                       Florida
# 10        13                       Georgia
# 11        15                        Hawaii
# 12        16                         Idaho
# 13        17                      Illinois
# 14        18                       Indiana
# 15        19                          Iowa
# 16        20                        Kansas
# 17        21                      Kentucky
# 18        22                     Louisiana
# 19        23                         Maine
# 20        24                      Maryland
# ...

# %%
# -- This is at the city level - come to this later
df_data_city = pd.read_csv('C:/Users/Kiran/Desktop/NSS/Capstone/data/laus/data_city',sep='\t',header=(0))
df_data_city.columns = df_data_city.columns.str.lower().str.strip()
df_data_city
# Out:
#                               series_id  year period    value footnote_codes
# 0        LASCT365100000000003            1976    M01     11.2            NaN
# 1        LASCT365100000000003            1976    M02     11.2            NaN
# 2        LASCT365100000000003            1976    M03     11.2            NaN
# 3        LASCT365100000000003            1976    M04     11.1            NaN
# 4        LASCT365100000000003            1976    M05     11.1            NaN
# ...                                 ...   ...    ...      ...            ...
# 5570669  LAUCT564505000000006            2023    M10  18336.0            NaN
# 5570670  LAUCT564505000000006            2023    M11  18801.0            NaN
# 5570671  LAUCT564505000000006            2023    M12  18201.0              P
# 5570672  LAUCT564505000000006            2024    M01  17903.0            NaN
# 5570673  LAUCT564505000000006            2024    M02  18405.0              P
#
# [5570674 rows x 5 columns]

# %%
df_ref_area_type = pd.read_csv('C:/Users/Kiran/Desktop/NSS/Capstone/data/laus/ref_area_type',sep='\t',header=(0))
df_ref_area_type.columns = df_ref_area_type.columns.str.lower().str.strip()
df_ref_area_type
# Out:
#    area_type_code                                      areatype_text
# 0               A                                          Statewide
# 1               B                                 Metropolitan areas
# 2               C                             Metropolitan divisions
# 3               D                                 Micropolitan areas
# 4               E                                     Combined areas
# 5               F                           Counties and equivalents
# 6               G           Cities and towns above 25,000 population
# 7               H  Cities and towns below 25,000 population in Ne...
# 8               I       Parts of cities that cross county boundaries
# 9               J              Multi-entity small labor market areas
# 10              K               Intrastate parts of interstate areas
# 11              L                             Balance of state areas
# 12              M                                     Census regions
# ...

# %%
#df_comb1 = pd.merge(df_data_hawaii, df_ref_period, on = 'period', how = 'inner')

pd.merge(df_data_combined_states, df_ref_series, on = 'series_id', how = 'inner')
# Out:
#                               series_id  year period      value  \
# 0        LASST020000000000003            1976    M01        7.1
# 1        LASST020000000000003            1976    M02        7.1
# 2        LASST020000000000003            1976    M03        7.0
# 3        LASST020000000000003            1976    M04        6.9
# 4        LASST020000000000003            1976    M05        6.9
# ...                                 ...   ...    ...        ...
# 2569993  LAUST530000000000009            2023    M11  6278911.0
# 2569994  LAUST530000000000009            2023    M12  6283111.0
# 2569995  LAUST530000000000009            2023    M13  6257779.0
# 2569996  LAUST530000000000009            2024    M01  6286991.0
# 2569997  LAUST530000000000009            2024    M02  6290857.0
#
#         footnote_codes_x area_type_code        area_code  measure_code  \
# 0                    NaN              A  ST0200000000000             3
# ...

# %%
df_data_combined_states = pd.merge(df_data_combined_states, df_ref_series, on = 'series_id', how = 'inner', suffixes=('__df_data_combined_states', '__df_ref_series'))

# %%
df_data_combined_states.head(2)
# Out:
#                         series_id  year period  value  \
# 0  LASST020000000000003            1976    M01    7.1
# 1  LASST020000000000003            1976    M02    7.1
#
#   footnote_codes__df_data_combined_states area_type_code        area_code  \
# 0                                     NaN              A  ST0200000000000
# 1                                     NaN              A  ST0200000000000
#
#    measure_code seasonal  srd_code                   series_title  \
# 0             3        S         2  Unemployment Rate: Alaska (S)
# 1             3        S         2  Unemployment Rate: Alaska (S)
#
#   footnote_codes__df_ref_series  begin_year begin_period  end_year end_period
# 0                           NaN        1976          M01      2024        M02
# 1                           NaN        1976          M01      2024        M02

# %%
df_ref_states
df_data_combined_states = pd.merge(df_data_combined_states, df_ref_states, on = 'srd_code', how = 'inner', suffixes=('__df_data_combined_states', '__df_ref_states'))
df_data_combined_states.head(2)
# Out:
#                         series_id  year period  value  \
# 0  LASST020000000000003            1976    M01    7.1
# 1  LASST020000000000003            1976    M02    7.1
# 2  LASST020000000000003            1976    M03    7.0
# 3  LASST020000000000003            1976    M04    6.9
# 4  LASST020000000000003            1976    M05    6.9
#
#   footnote_codes__df_data_combined_states area_type_code        area_code  \
# 0                                     NaN              A  ST0200000000000
# 1                                     NaN              A  ST0200000000000
# 2                                     NaN              A  ST0200000000000
# 3                                     NaN              A  ST0200000000000
# 4                                     NaN              A  ST0200000000000
#
#    measure_code seasonal  srd_code                   series_title  \
# 0             3        S         2  Unemployment Rate: Alaska (S)
# ...

# %%
df_ref_measure
df_data_combined_states = pd.merge(df_data_combined_states, df_ref_measure, on = 'measure_code', how = 'inner', suffixes=('__df_data_combined_states', '__df_ref_measure'))
df_data_combined_states.head()
# Out:
#                         series_id  year period  value  \
# 0  LASST020000000000003            1976    M01    7.1
# 1  LASST020000000000003            1976    M02    7.1
# 2  LASST020000000000003            1976    M03    7.0
# 3  LASST020000000000003            1976    M04    6.9
# 4  LASST020000000000003            1976    M05    6.9
#
#   footnote_codes__df_data_combined_states area_type_code        area_code  \
# 0                                     NaN              A  ST0200000000000
# 1                                     NaN              A  ST0200000000000
# 2                                     NaN              A  ST0200000000000
# 3                                     NaN              A  ST0200000000000
# 4                                     NaN              A  ST0200000000000
#
#    measure_code seasonal  srd_code                   series_title  \
# 0             3        S         2  Unemployment Rate: Alaska (S)
# ...

# %%
df_ref_period
df_data_combined_states = pd.merge(df_data_combined_states, df_ref_period, on = 'period', how = 'inner', suffixes=('__df_data_combined_states', '__df_ref_period'))
df_data_combined_states.head()
# Out:
#                         series_id  year period  value  \
# 0  LASST020000000000003            1976    M01    7.1
# 1  LASST020000000000003            1977    M01    9.1
# 2  LASST020000000000003            1978    M01   10.9
# 3  LASST020000000000003            1979    M01    9.6
# 4  LASST020000000000003            1980    M01    8.7
#
#   footnote_codes__df_data_combined_states area_type_code        area_code  \
# 0                                     NaN              A  ST0200000000000
# 1                                     NaN              A  ST0200000000000
# 2                                     NaN              A  ST0200000000000
# 3                                     NaN              A  ST0200000000000
# 4                                     NaN              A  ST0200000000000
#
#    measure_code seasonal  srd_code                   series_title  \
# 0             3        S         2  Unemployment Rate: Alaska (S)
# ...

# %%
df_ref_area_type
df_data_combined_states = pd.merge(df_data_combined_states, df_ref_area_type, on = 'area_type_code', how = 'inner', suffixes=('__df_data_combined_states', '__df_ref_area_type'))
# Out:
#    area_type_code                                      areatype_text
# 0               A                                          Statewide
# 1               B                                 Metropolitan areas
# 2               C                             Metropolitan divisions
# 3               D                                 Micropolitan areas
# 4               E                                     Combined areas
# 5               F                           Counties and equivalents
# 6               G           Cities and towns above 25,000 population
# 7               H  Cities and towns below 25,000 population in Ne...
# 8               I       Parts of cities that cross county boundaries
# 9               J              Multi-entity small labor market areas
# 10              K               Intrastate parts of interstate areas
# 11              L                             Balance of state areas
# 12              M                                     Census regions
# ...

# %%
df_ref_seasonal
df_data_combined_states = pd.merge(df_data_combined_states, df_ref_seasonal, left_on='seasonal', right_on='seasonal_code', how = 'inner', suffixes=('__df_data_combined_states', '__df_ref_seasonal'))

# %%
pd.set_option('display.max_columns', None)
df_data_combined_states['year'].unique()
#df_data_combined_states
df_data_combined_statewide_only = df_data_combined_states[(df_data_combined_states['area_type_code'] == "A") & (df_data_combined_states['seasonal_code'] == "U")].copy()
#df_data_combined_statewide_only.info()
#df_data_combined_states['begin_year'].unique()
df_data_combined_statewide_2010above_only = df_data_combined_statewide_only[(df_data_combined_statewide_only.year >= 2010)].copy()
df_data_combined_statewide_2010above_only
# Out:
#                             series_id  year period      value  \
# 39150  LAUST020000000000003            2010    M01        9.3
# 39151  LAUST020000000000003            2011    M01        9.0
# 39152  LAUST020000000000003            2012    M01        8.3
# 39153  LAUST020000000000003            2013    M01        8.3
# 39154  LAUST020000000000003            2014    M01        7.7
# ...                               ...   ...    ...        ...
# 69785  LAUST530000000000009            2019    M13  6029945.0
# 69786  LAUST530000000000009            2020    M13  6104497.0
# 69787  LAUST530000000000009            2021    M13  6146147.0
# 69788  LAUST530000000000009            2022    M13  6203580.0
# 69789  LAUST530000000000009            2023    M13  6257779.0
#
#       footnote_codes__df_data_combined_states area_type_code        area_code  \
# 39150                                     NaN              A  ST0200000000000
# ...

# %%
df_data_combined_statewide_2010above_only['srd_text']
# Out:
# 39150        Alaska
# 39151        Alaska
# 39152        Alaska
# 39153        Alaska
# 39154        Alaska
#             ...
# 69785    Washington
# 69786    Washington
# 69787    Washington
# 69788    Washington
# 69789    Washington
# Name: srd_text, Length: 9016, dtype: object

# %%
df_data_combined_statewide_2010above_only.year.unique()
# Out:
# array([2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020,
#        2021, 2022, 2023, 2024], dtype=int64)

# %%
df_data_combined_statewide_2010above_only.series_title.value_counts()
# Out:
# series_title
# Unemployment Rate: Alaska (U)                           184
# Labor Force: Tennessee (U)                              184
# Labor Force: Washington (U)                             184
# Employment-Population Ratio: Alaska (U)                 184
# Employment-Population Ratio: California (U)             184
# Employment-Population Ratio: Hawaii (U)                 184
# Employment-Population Ratio: New York (U)               184
# Employment-Population Ratio: Tennessee (U)              184
# Employment-Population Ratio: Texas (U)                  184
# Employment-Population Ratio: Washington (U)             184
# Labor Force Participation Rate: Alaska (U)              184
# Labor Force Participation Rate: California (U)          184
# Labor Force Participation Rate: Hawaii (U)              184
# Labor Force Participation Rate: New York (U)            184
# Labor Force Participation Rate: Tennessee (U)           184
# ...

# %%
df_data_combined_statewide_2010above_only.measure_text.value_counts()
# Out:
# measure_text
# unemployment rate                       1288
# unemployment                            1288
# employment                              1288
# labor force                             1288
# employment-population ratio             1288
# labor force participation rate          1288
# civilian noninstitutional population    1288
# Name: count, dtype: int64

# %%
df_data_combined_statewide_2010above_only.query('measure_text == "unemployment rate" & period_name == "Annual Average"')
# Out:
#                             series_id  year period  value  \
# 67472  LAUST020000000000003            2010    M13    8.2
# 67473  LAUST020000000000003            2011    M13    7.8
# 67474  LAUST020000000000003            2012    M13    7.2
# 67475  LAUST020000000000003            2013    M13    7.0
# 67476  LAUST020000000000003            2014    M13    6.7
# ...                               ...   ...    ...    ...
# 67769  LAUST530000000000003            2019    M13    4.2
# 67770  LAUST530000000000003            2020    M13    8.5
# 67771  LAUST530000000000003            2021    M13    5.2
# 67772  LAUST530000000000003            2022    M13    4.1
# 67773  LAUST530000000000003            2023    M13    4.1
#
#       footnote_codes__df_data_combined_states area_type_code        area_code  \
# 67472                                     NaN              A  ST0200000000000
# 67473                                     NaN              A  ST0200000000000
# ...

# %%
plt.figure(figsize = (15,5)) 
plt.plot(df_data_combined_statewide_2010above_only['srd_text'],
        df_data_combined_statewide_2010above_only['year'])

# %% [markdown]
# years_to_keep = list(range(2012, 2021))  #2012 to 2020 [YES]
# Healthcare_coverage = Healthcare_coverage[Healthcare_coverage['TIME_PERIOD'].isin(years_to_keep)]
# Healthcare_coverage.TIME_PERIOD.value_counts()
# Healthcare_coverage.reset_index(drop= True)
# #went form 10952 rows down to 2757
